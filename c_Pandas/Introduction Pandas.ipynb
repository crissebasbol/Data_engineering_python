# %% [markdown]
# # Series

# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48,
                          2000: 65,
                          2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
frame_test = pd.DataFrame({1999: [47, 38, 39],
                           2000: [34, 32, 32],
                           2001: [23, 39, 23]})
                           
frame_test
# Out:
#    1999  2000  2001
# 0    47    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[47, 38, 39],
                          [34, 32, 32],
                          [23, 39, 23]], columns=[1999, 2000, 2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    47    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# # Read data

# %%
el_universal = pd.read_csv("../b_Web_scraping/web_scrapper/eluniversal_2020_05_08_articles.csv", encoding="ISO-8859-1")

type(el_universal)
# Out:
# pandas.core.frame.DataFrame

# %%
el_universal
# Out:
#                                         article_links  \
# 0   https://www.eluniversal.com.mx/ciencia-y-salud...
# 1   https://www.eluniversal.com.mx/cartera/reporta...
# 2              https://www.eluniversal.com.mx/techbit
# 3   https://www.eluniversal.com.mx/autor-opinion/c...
# 4   https://www.eluniversal.com.mx/estados/reporta...
# ..                                                ...
# 93  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 94            https://www.eluniversal.com.mx/deportes
# 95  https://www.eluniversal.com.mx/nacion/coronavi...
# 96  https://www.eluniversal.com.mx/estados/aumenta...
# 97  https://www.eluniversal.com.mx/nacion/segurida...
#
#                                                  body  \
# 0   De acuerdo a la información otorgada por las a...
# 1   Debido a la falta de producción de cerveza, el...
# 2                                                 NaN
# 3                                                 NaN
# ...

# %%
el_universal.head()
# muestra los primeros 5 datos
# Out:
#                                        article_links  \
# 0  https://www.eluniversal.com.mx/ciencia-y-salud...
# 1  https://www.eluniversal.com.mx/cartera/reporta...
# 2             https://www.eluniversal.com.mx/techbit
# 3  https://www.eluniversal.com.mx/autor-opinion/c...
# 4  https://www.eluniversal.com.mx/estados/reporta...
#
#                                                 body  \
# 0  De acuerdo a la información otorgada por las a...
# 1  Debido a la falta de producción de cerveza, el...
# 2                                                NaN
# 3                                                NaN
# 4  Un grupo delincuencial bloqueó la autopista Pu...
#
#                                                title
# 0  ¿Qué pasará después de alcanzar el pico más al...
# 1  Reporta cerveza mayor alza de precio en 10 año...
# 2  Facebook y Google extienden el trabajo desde c...
# 3                                 Óscar Mario Beteta
# 4  Reportan robo masivo en la autopista Puebla-Ve...

# %%
el_universal.tail()
# muestra los últimos 5 datos
# Out:
#                                         article_links  \
# 93  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 94            https://www.eluniversal.com.mx/deportes
# 95  https://www.eluniversal.com.mx/nacion/coronavi...
# 96  https://www.eluniversal.com.mx/estados/aumenta...
# 97  https://www.eluniversal.com.mx/nacion/segurida...
#
#                                                  body  \
# 93  Bienvenidos una vez más a su sección favorita ...
# 94                                                NaN
# 95  El vocero de Presidencia, Jesús Ramírez Cuevas...
# 96  Monterrey.- El total de personas que dieron po...
# 97  Zoé Robledo, director General del Instituto Me...
#
#                                                 title
# 93  Y la peor vestida de la semana es
#  Linet Puent...
# 94  Paco Jémez revela a sus consentidos del Cruz Azul
# 95  Presidencia rechaza que gobierno federal ocult...
# 96  Aumentan a 66 los contagios en asilo de ancian...
# ...

# %%
pd.options.display.max_rows=10
el_universal
# Out:
#                                         article_links  \
# 0   https://www.eluniversal.com.mx/ciencia-y-salud...
# 1   https://www.eluniversal.com.mx/cartera/reporta...
# 2              https://www.eluniversal.com.mx/techbit
# 3   https://www.eluniversal.com.mx/autor-opinion/c...
# 4   https://www.eluniversal.com.mx/estados/reporta...
# ..                                                ...
# 93  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 94            https://www.eluniversal.com.mx/deportes
# 95  https://www.eluniversal.com.mx/nacion/coronavi...
# 96  https://www.eluniversal.com.mx/estados/aumenta...
# 97  https://www.eluniversal.com.mx/nacion/segurida...
#
#                                                  body  \
# 0   De acuerdo a la información otorgada por las a...
# 1   Debido a la falta de producción de cerveza, el...
# 2                                                 NaN
# 3                                                 NaN
# ...

# %% [markdown]
# # Index and selection

# %%
# dictionary like

el_universal["title"]
# Out:
# 0     ¿Qué pasará después de alcanzar el pico más al...
# 1     Reporta cerveza mayor alza de precio en 10 año...
# 2     Facebook y Google extienden el trabajo desde c...
# 3                                    Óscar Mario Beteta
# 4     Reportan robo masivo en la autopista Puebla-Ve...
#                             ...
# 93    Y la peor vestida de la semana es
#  Linet Puent...
# 94    Paco Jémez revela a sus consentidos del Cruz Azul
# 95    Presidencia rechaza que gobierno federal ocult...
# 96    Aumentan a 66 los contagios en asilo de ancian...
# 97    Inaceptable, asesinato de trabajadoras del IMS...
# Name: title, Length: 98, dtype: object

# %%
el_universal[["title", "article_links"]]
# Out:
#                                                 title  \
# 0   ¿Qué pasará después de alcanzar el pico más al...
# 1   Reporta cerveza mayor alza de precio en 10 año...
# 2   Facebook y Google extienden el trabajo desde c...
# 3                                  Óscar Mario Beteta
# 4   Reportan robo masivo en la autopista Puebla-Ve...
# ..                                                ...
# 93  Y la peor vestida de la semana es
#  Linet Puent...
# 94  Paco Jémez revela a sus consentidos del Cruz Azul
# 95  Presidencia rechaza que gobierno federal ocult...
# 96  Aumentan a 66 los contagios en asilo de ancian...
# 97  Inaceptable, asesinato de trabajadoras del IMS...
#
#                                         article_links
# 0   https://www.eluniversal.com.mx/ciencia-y-salud...
# 1   https://www.eluniversal.com.mx/cartera/reporta...
# 2              https://www.eluniversal.com.mx/techbit
# 3   https://www.eluniversal.com.mx/autor-opinion/c...
# ...

# %%
# Numpy like

el_universal.iloc[10:15]
# Out:
#                                         article_links  \
# 10  https://www.eluniversal.com.mx/autor-opinion/p...
# 11           https://www.eluniversal.com.mx/de-ultima
# 12  https://www.eluniversal.com.mx/cartera/identif...
# 13  https://www.eluniversal.com.mx/menu/como-cocin...
# 14  https://www.eluniversal.com.mx/universal-depor...
#
#                                                  body  \
# 10                                                NaN
# 11                                                NaN
# 12  La secretaria de Economía, Graciela Márquez, i...
# 13  Los tacos de suadero son un platillo originari...
# 14  El futbol está detenido, pero los equipos y su...
#
#                                                 title
# 10                                       Martí Batres
# 11  Danna Paola deslumbra con costoso collar de co...
# 12  Identifican con nombres y apellido a microempr...
# 13      Cuál es la mejor manera de cocinar el suadero
# ...

# %%
el_universal.iloc[66]["title"]
# Out:
# 'México supera los 3 mil muertos por Covid; suman 31,522 contagios'

# %%
el_universal.iloc[:5,0]
# Out:
# 0    https://www.eluniversal.com.mx/ciencia-y-salud...
# 1    https://www.eluniversal.com.mx/cartera/reporta...
# 2               https://www.eluniversal.com.mx/techbit
# 3    https://www.eluniversal.com.mx/autor-opinion/c...
# 4    https://www.eluniversal.com.mx/estados/reporta...
# Name: article_links, dtype: object

# %%
el_universal.loc[:, "body": "title"]
# Out:
#                                                  body  \
# 0   De acuerdo a la información otorgada por las a...
# 1   Debido a la falta de producción de cerveza, el...
# 2                                                 NaN
# 3                                                 NaN
# 4   Un grupo delincuencial bloqueó la autopista Pu...
# ..                                                ...
# 93  Bienvenidos una vez más a su sección favorita ...
# 94                                                NaN
# 95  El vocero de Presidencia, Jesús Ramírez Cuevas...
# 96  Monterrey.- El total de personas que dieron po...
# 97  Zoé Robledo, director General del Instituto Me...
#
#                                                 title
# 0   ¿Qué pasará después de alcanzar el pico más al...
# 1   Reporta cerveza mayor alza de precio en 10 año...
# 2   Facebook y Google extienden el trabajo desde c...
# 3                                  Óscar Mario Beteta
# ...

# %%
el_universal.loc[1:5]
# Out:
#                                        article_links  \
# 1  https://www.eluniversal.com.mx/cartera/reporta...
# 2             https://www.eluniversal.com.mx/techbit
# 3  https://www.eluniversal.com.mx/autor-opinion/c...
# 4  https://www.eluniversal.com.mx/estados/reporta...
# 5  https://www.eluniversal.com.mx/nacion/presiden...
#
#                                                 body  \
# 1  Debido a la falta de producción de cerveza, el...
# 2                                                NaN
# 3                                                NaN
# 4  Un grupo delincuencial bloqueó la autopista Pu...
# 5  Jesús Ramírez, vocero de la Presidencia de la ...
#
#                                                title
# 1  Reporta cerveza mayor alza de precio en 10 año...
# 2  Facebook y Google extienden el trabajo desde c...
# 3                                 Óscar Mario Beteta
# 4  Reportan robo masivo en la autopista Puebla-Ve...
# 5  Presidencia sigue pleito con Calderón; asegura...

# %%
el_universal.loc[1]
# Out:
# article_links    https://www.eluniversal.com.mx/cartera/reporta...
# body             Debido a la falta de producción de cerveza, el...
# title            Reporta cerveza mayor alza de precio en 10 año...
# Name: 1, dtype: object

# %% [markdown]
# # Data wrangling

# %%
# 1. Añadir newspaper_uid al DataFrame

el_universal["newspapes_uid"] = "eluniversal"

el_universal
# Out:
#                                         article_links  \
# 0   https://www.eluniversal.com.mx/ciencia-y-salud...
# 1   https://www.eluniversal.com.mx/cartera/reporta...
# 2              https://www.eluniversal.com.mx/techbit
# 3   https://www.eluniversal.com.mx/autor-opinion/c...
# 4   https://www.eluniversal.com.mx/estados/reporta...
# ..                                                ...
# 93  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 94            https://www.eluniversal.com.mx/deportes
# 95  https://www.eluniversal.com.mx/nacion/coronavi...
# 96  https://www.eluniversal.com.mx/estados/aumenta...
# 97  https://www.eluniversal.com.mx/nacion/segurida...
#
#                                                  body  \
# 0   De acuerdo a la información otorgada por las a...
# 1   Debido a la falta de producción de cerveza, el...
# 2                                                 NaN
# 3                                                 NaN
# ...

# %%
# 2. Obtener el host

from urllib.parse import urlparse

# apply -> nos permite generar transformaciones custom que nosotros requeramos
el_universal["host"] = el_universal["article_links"].apply(lambda article_links: urlparse(article_links).netloc)

el_universal
# Out:
#                                         article_links  \
# 0   https://www.eluniversal.com.mx/ciencia-y-salud...
# 1   https://www.eluniversal.com.mx/cartera/reporta...
# 2              https://www.eluniversal.com.mx/techbit
# 3   https://www.eluniversal.com.mx/autor-opinion/c...
# 4   https://www.eluniversal.com.mx/estados/reporta...
# ..                                                ...
# 93  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 94            https://www.eluniversal.com.mx/deportes
# 95  https://www.eluniversal.com.mx/nacion/coronavi...
# 96  https://www.eluniversal.com.mx/estados/aumenta...
# 97  https://www.eluniversal.com.mx/nacion/segurida...
#
#                                                  body  \
# 0   De acuerdo a la información otorgada por las a...
# 1   Debido a la falta de producción de cerveza, el...
# 2                                                 NaN
# 3                                                 NaN
# ...

# %%
el_universal["host"].value_counts()
# Out:
# www.eluniversal.com.mx    98
# Name: host, dtype: int64

# %% [markdown]
# # Missing data

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal["title"].isna()
missing_titles_mask.value_counts()
# Out:
# False    98
# Name: title, dtype: int64

# %%
# como en el título no tenemos datos faltantes, intentamos con el body
missing_bodies_mask = el_universal["body"].isna()
missing_bodies_mask.value_counts()
# Out:
# False    79
# True     19
# Name: body, dtype: int64

# %%
missing_bodies_mask
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 93    False
# 94     True
# 95    False
# 96    False
# 97    False
# Name: body, Length: 98, dtype: bool

# %%
# en el body vamos a colocar el texto del último pedazo de la url
# [^/]-->queremos que haga match hasta que no encuentre una diagonal adicional
# [^/]+-->que esto puede suceder una o más veces
# ([^/]+)$ --> vamos ir hasta el final de nuestro string 
# (?P<missing_bodies>[^/]+)$ --> colocar un nombre al grupo
el_universal[missing_bodies_mask]["article_links"].str.extract(r"(?P<missing_bodies>[^/]+)$")
# Out:
#            missing_bodies
# 2                 techbit
# 3         en-petit-comite
# 7                 cartera
# 8           plata-o-plomo
# 10           marti-batres
# ..                    ...
# 55           espectaculos
# 71               destinos
# 82  raul-rodriguez-cortes
# 86                   menu
# 94               deportes
#
# [19 rows x 1 columns]

# %%
# applymap nos permite generar un mapa de un valor a otro, es decir una transformación
missing_bodies = (el_universal[missing_bodies_mask]["article_links"]
                     .str.extract(r"(?P<missing_bodies>[^/]+)$")
                     .applymap(lambda body: body.split("-"))
                     .applymap(lambda body_word_list: " ".join(body_word_list))
                 )
missing_bodies
# Out:
#            missing_bodies
# 2                 techbit
# 3         en petit comite
# 7                 cartera
# 8           plata o plomo
# 10           marti batres
# ..                    ...
# 55           espectaculos
# 71               destinos
# 82  raul rodriguez cortes
# 86                   menu
# 94               deportes
#
# [19 rows x 1 columns]

# %%
el_universal.loc[missing_bodies_mask, "body"] = missing_bodies.loc[:, "missing_bodies"]
el_universal
# Out:
#                                         article_links  \
# 0   https://www.eluniversal.com.mx/ciencia-y-salud...
# 1   https://www.eluniversal.com.mx/cartera/reporta...
# 2              https://www.eluniversal.com.mx/techbit
# 3   https://www.eluniversal.com.mx/autor-opinion/c...
# 4   https://www.eluniversal.com.mx/estados/reporta...
# ..                                                ...
# 93  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 94            https://www.eluniversal.com.mx/deportes
# 95  https://www.eluniversal.com.mx/nacion/coronavi...
# 96  https://www.eluniversal.com.mx/estados/aumenta...
# 97  https://www.eluniversal.com.mx/nacion/segurida...
#
#                                                  body  \
# 0   De acuerdo a la información otorgada por las a...
# 1   Debido a la falta de producción de cerveza, el...
# 2                                             techbit
# 3                                     en petit comite
# ...

# %% [markdown]
# # Additional cleanup

# %%
el_universal
# Out:
#                                         article_links  \
# 0   https://www.eluniversal.com.mx/ciencia-y-salud...
# 1   https://www.eluniversal.com.mx/cartera/reporta...
# 2              https://www.eluniversal.com.mx/techbit
# 3   https://www.eluniversal.com.mx/autor-opinion/c...
# 4   https://www.eluniversal.com.mx/estados/reporta...
# ..                                                ...
# 93  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 94            https://www.eluniversal.com.mx/deportes
# 95  https://www.eluniversal.com.mx/nacion/coronavi...
# 96  https://www.eluniversal.com.mx/estados/aumenta...
# 97  https://www.eluniversal.com.mx/nacion/segurida...
#
#                                                  body  \
# 0   De acuerdo a la información otorgada por las a...
# 1   Debido a la falta de producción de cerveza, el...
# 2                                             techbit
# 3                                     en petit comite
# ...

# %%
# 4. Añadir uid a las filas
import hashlib
#hashlib --> normalmente se utiliza para operaciones criptográficas, pero la vamos a utilziar para generar un hash
#            de la URL, de tal manera que tengamos un número único que mapee siempre a esa URL

# axis=0 -->columbas
# axis=1 -->filas
uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row["article_links"].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
        )
el_universal["uid"] = uids
# inplace --> le indica que queremos modificar directamente nuestra tabla 
el_universal.set_index("uid", inplace=True)
el_universal
# Out:
#                                                                       article_links  \
# uid
# 098de4ecd15982dd560aaf0e6a88c8b4  https://www.eluniversal.com.mx/ciencia-y-salud...
# 1a41c134f0f66f9589e36defb6d262de  https://www.eluniversal.com.mx/cartera/reporta...
# 48589abcd344d8016f654e7393c24335             https://www.eluniversal.com.mx/techbit
# 50c26b926f6bc5bcee8f423d256a7e6f  https://www.eluniversal.com.mx/autor-opinion/c...
# 7e6b88c65efb6b4555b384965bf901c6  https://www.eluniversal.com.mx/estados/reporta...
# ...                                                                             ...
# 4c05538cf0630c60f79918f7009aedaa  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 19ef3c9529ab8fbd3d3bece5ce0d94ca            https://www.eluniversal.com.mx/deportes
# 7060d450b122cf8cf2c50d9766250f52  https://www.eluniversal.com.mx/nacion/coronavi...
# 73874492fa9fbb00a38f876a035db2cd  https://www.eluniversal.com.mx/estados/aumenta...
# ...

# %%
# ahora vamos a eliminar los salto de linea presentes en algunos body

stripped_body = (el_universal
                     .apply(lambda row: row["body"], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace("\n", ""), letters)))
                     .apply(lambda letters: list(map(lambda letter: letter.replace("\r", ""), letters)))
                     .apply(lambda letters: "".join(letters))
                )
stripped_body
# Out:
# uid
# 098de4ecd15982dd560aaf0e6a88c8b4    De acuerdo a la información otorgada por las a...
# 1a41c134f0f66f9589e36defb6d262de    Debido a la falta de producción de cerveza, el...
# 48589abcd344d8016f654e7393c24335                                              techbit
# 50c26b926f6bc5bcee8f423d256a7e6f                                      en petit comite
# 7e6b88c65efb6b4555b384965bf901c6    Un grupo delincuencial bloqueó la autopista Pu...
#                                                           ...
# 4c05538cf0630c60f79918f7009aedaa    Bienvenidos una vez más a su sección favorita ...
# 19ef3c9529ab8fbd3d3bece5ce0d94ca                                             deportes
# 7060d450b122cf8cf2c50d9766250f52    El vocero de Presidencia, Jesús Ramírez Cuevas...
# 73874492fa9fbb00a38f876a035db2cd    Monterrey.- El total de personas que dieron po...
# 23a2736b7e0df2dc7caa3225464bb8ad    Zoé Robledo, director General del Instituto Me...
# Length: 98, dtype: object

# %% [markdown]
# # Data enrichment

# %%
# 6. tokenizar el título y el body
import nltk
# nltk: Ayuda a trabjar con lenguage natural
from nltk.corpus import stopwords
# stopwords : son palabras que no añaden ningún tipo de analisis posterior, por ejemplo "el, la", 
# palabras que se utilizan mucho en el lenguage pero no ayudan a determinar que está sucedienendo 
# dentro de nuestro análisis de texto

# si nunca hemos corrido nltk, nos va a pedir que bajemos los archivos adicionales, instalarla no 
# es suficiente porque es una librería enorme, entonces la primera vez que corremos esta librería, 
# nos pide que ajemos las librerías adicionales, se debe colocar el siguiente código, de lo contrario
# se debe comentar las siguientes dos líneas:

nltk.download("punkt")
# punkt: librería para poder tokenizar, es decir dividir en palabras
nltk.download("stopwords")

stop_words = set(stopwords.words("spanish"))
# los stop_words: vienen en minúsuculas
stop_words
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cris-\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cris-\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'a',
#  'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
# ...

# %%
# una función que nos va a generar las transformaciones en la columna deseada (primero título y luego enn el body)
def tokenize_column(df, column_name):
    return (df
               .dropna() # Eliminamos las que no tienen datos, de lo contrario nltk existirá un error.
               .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
               .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens))) # Eliminar palabras que no sean alfanuméricas
               .apply(lambda tokens: list(map(lambda token: token.lower(), tokens))) # convertir todos los tokesns a lowerCase
               .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list))) # Eliminar las palabras que sean stop_words
               .apply(lambda valid_word_list: len(valid_word_list)) # obtener la longitud que tiene cada una de estas listas
           )

el_universal["n_tokens_title"] = tokenize_column(el_universal, "title")

# en la columna "n_tokens_title": nos dice cual es el valor de nuestros tokens, por ejemeplos si un título 
# "Hamilton con otra pole para su legado", da un valor de 3, esto quiere decir que del título solo 3 palabras son 
# significativas ("hamilton", "pole" y "legado").
el_universal
# Out:
#                                                                       article_links  \
# uid
# 098de4ecd15982dd560aaf0e6a88c8b4  https://www.eluniversal.com.mx/ciencia-y-salud...
# 1a41c134f0f66f9589e36defb6d262de  https://www.eluniversal.com.mx/cartera/reporta...
# 48589abcd344d8016f654e7393c24335             https://www.eluniversal.com.mx/techbit
# 50c26b926f6bc5bcee8f423d256a7e6f  https://www.eluniversal.com.mx/autor-opinion/c...
# 7e6b88c65efb6b4555b384965bf901c6  https://www.eluniversal.com.mx/estados/reporta...
# ...                                                                             ...
# 4c05538cf0630c60f79918f7009aedaa  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 19ef3c9529ab8fbd3d3bece5ce0d94ca            https://www.eluniversal.com.mx/deportes
# 7060d450b122cf8cf2c50d9766250f52  https://www.eluniversal.com.mx/nacion/coronavi...
# 73874492fa9fbb00a38f876a035db2cd  https://www.eluniversal.com.mx/estados/aumenta...
# ...

# %%
el_universal["n_tokens_body"] = tokenize_column(el_universal, "body")

el_universal
# Out:
#                                                                       article_links  \
# uid
# 098de4ecd15982dd560aaf0e6a88c8b4  https://www.eluniversal.com.mx/ciencia-y-salud...
# 1a41c134f0f66f9589e36defb6d262de  https://www.eluniversal.com.mx/cartera/reporta...
# 48589abcd344d8016f654e7393c24335             https://www.eluniversal.com.mx/techbit
# 50c26b926f6bc5bcee8f423d256a7e6f  https://www.eluniversal.com.mx/autor-opinion/c...
# 7e6b88c65efb6b4555b384965bf901c6  https://www.eluniversal.com.mx/estados/reporta...
# ...                                                                             ...
# 4c05538cf0630c60f79918f7009aedaa  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 19ef3c9529ab8fbd3d3bece5ce0d94ca            https://www.eluniversal.com.mx/deportes
# 7060d450b122cf8cf2c50d9766250f52  https://www.eluniversal.com.mx/nacion/coronavi...
# 73874492fa9fbb00a38f876a035db2cd  https://www.eluniversal.com.mx/estados/aumenta...
# ...

# %% [markdown]
# # Duplicate values

# %%
# 8. Eliminar duplicados

el_universal["article_links"].value_counts()
# Out:
# https://www.eluniversal.com.mx/cartera                                                                  1
# https://www.eluniversal.com.mx/nacion                                                                   1
# https://www.eluniversal.com.mx/menu/el-iconico-restaurante-sir-winston-churchills-cerro-sus-puertas     1
# https://www.eluniversal.com.mx/universal-deportes/futbol/fifa-autoriza-5-cambios-y-desaparece-el-var    1
# https://www.eluniversal.com.mx/autor-opinion/columnistas/raul-rodriguez-cortes/raul-rodriguez-cortes    1
#                                                                                                        ..
# https://www.eluniversal.com.mx/estados/clases-online-sin-computadora-en-casa                            1
# https://www.eluniversal.com.mx/universal-deportes/futbol/cruz-azul-se-filtra-nuevo-uniforme             1
# https://www.eluniversal.com.mx/mundo/preven-dos-rebrotes-mas-del-coronavirus-en-espana                  1
# ...

# %%
el_universal["title"].value_counts()
# Out:
# Prevén dos rebrotes más del coronavirus en España                                              2
# Sir Winston Churchill's cierra sus puertas                                                     2
# El papel de los videojuegos en el manejo autónomo                                              2
# National Geographic estrenará barco de crucero para viajar a regiones polares                  2
# Tata Martino lanza convocatoria especial                                                     1
#                                                                                               ..
# "Llama la atención la sincronía": López-Gatell sobre notas que cuestionan conteo de muertos    1
# Regresó el Tenis en vivo en Estados Unidos                                                     1
# Prepara un delicioso cheesecake de frutos rojos                                                1
# El coronavirus deja sedientos de cerveza a los mexicanos                                       1
# ...

# %%
el_universal[el_universal["title"] == "El papel de los videojuegos en el manejo autónomo"]
# Out:
#                                                                       article_links  \
# uid
# bf2cfb96ca6a2a90a4a28aa3f7e31cdc  https://www.eluniversal.com.mx/autopistas/que-...
# b1138c94ba63e43142a9518a1156805d          https://www.eluniversal.com.mx/autopistas
#
#                                                                                body  \
# uid
# bf2cfb96ca6a2a90a4a28aa3f7e31cdc  La firma de software de vehículos autónomos Ox...
# b1138c94ba63e43142a9518a1156805d                                         autopistas
#
#                                                                               title  \
# uid
# bf2cfb96ca6a2a90a4a28aa3f7e31cdc  El papel de los videojuegos en el manejo autónomo
# b1138c94ba63e43142a9518a1156805d  El papel de los videojuegos en el manejo autónomo
#
#                                  newspapes_uid                    host  \
# uid
# bf2cfb96ca6a2a90a4a28aa3f7e31cdc   eluniversal  www.eluniversal.com.mx
# ...

# %%
el_universal.drop_duplicates(subset=["title"], keep="first", inplace=True)
# keep: que tome los valores del primer duplicado o el último (last). 
# inplace = realizamos la modificación directamente.

# %%
el_universal["title"].value_counts()
# Out:
# Tata Martino lanza convocatoria especial                                                     1
# Policía Comunitaria en Guerrero toma las armas contra el Covid-19                              1
# El inusual vórtice polar que golpeará a Estados Unidos y partirá al país en dos                1
# Sir Winston Churchill's cierra sus puertas                                                     1
# Coronavirus Puebla: Casos confirmados de Covid-19 al 7 de mayo                                 1
#                                                                                               ..
# "Llama la atención la sincronía": López-Gatell sobre notas que cuestionan conteo de muertos    1
# Regresó el Tenis en vivo en Estados Unidos                                                     1
# Prevén dos rebrotes más del coronavirus en España                                              1
# Prepara un delicioso cheesecake de frutos rojos                                                1
# ...

# %% [markdown]
# # Final table

# %%
# Tabla final 
el_universal
# Out:
#                                                                       article_links  \
# uid
# 098de4ecd15982dd560aaf0e6a88c8b4  https://www.eluniversal.com.mx/ciencia-y-salud...
# 1a41c134f0f66f9589e36defb6d262de  https://www.eluniversal.com.mx/cartera/reporta...
# 48589abcd344d8016f654e7393c24335             https://www.eluniversal.com.mx/techbit
# 50c26b926f6bc5bcee8f423d256a7e6f  https://www.eluniversal.com.mx/autor-opinion/c...
# 7e6b88c65efb6b4555b384965bf901c6  https://www.eluniversal.com.mx/estados/reporta...
# ...                                                                             ...
# 4c05538cf0630c60f79918f7009aedaa  https://www.eluniversal.com.mx/de-ultima/la-pe...
# 19ef3c9529ab8fbd3d3bece5ce0d94ca            https://www.eluniversal.com.mx/deportes
# 7060d450b122cf8cf2c50d9766250f52  https://www.eluniversal.com.mx/nacion/coronavi...
# 73874492fa9fbb00a38f876a035db2cd  https://www.eluniversal.com.mx/estados/aumenta...
# ...

# %% [markdown]
# # Descriptive analysis

# %%
clean_eluniversal = pd.read_csv("eluniversal_2020_05_08_articles_cleaned.csv")
clean_elpais = pd.read_csv("elpais_2020_05_08_articles_cleaned.csv")

# %%
# El método describe nos otorga una serie de valores estadísticos que nos permiten 
# entender las distribuciones de nuestros datos. 

clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       94.000000      94.000000
# mean         5.723404      16.925532
# std          1.731456      11.715479
# min          2.000000       0.000000
# 25%          5.000000      10.000000
# 50%          6.000000      17.000000
# 75%          7.000000      23.000000
# max         11.000000      80.000000

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       94.000000      94.000000
# mean         5.723404      16.925532
# std          1.731456      11.715479
# min          2.000000       0.000000
# 25%          5.000000      10.000000
# 50%          6.000000      17.000000
# 75%          7.000000      23.000000
# max         11.000000      80.000000

# %%
clean_eluniversal.loc[clean_eluniversal["n_tokens_body"] == 0]
# Out:
#                                  uid                           article_links  \
# 43  53cb5621a414acf2092ea45f2e2efae5  https://www.eluniversal.com.mx/estados
#
#        body                                              title newspaper_uid  \
# 43  estados  Coronavirus deja sin sustento a músicos y flor...   eluniversal
#
#                       host  n_tokens_title  n_tokens_body
# 43  www.eluniversal.com.mx               5              0

# %%
# %matplotlib inline 
# para mostrar gráficos directamente en Jupyter

# k-->negro
# . --> gráfica de puntos o dispersión
clean_eluniversal["n_tokens_title"].plot(style="k.")
clean_elpais["n_tokens_title"].plot(style="r.")

# %%
clean_eluniversal["n_tokens_body"].plot(style="k.")
clean_elpais["n_tokens_body"].plot(style="r.")

# %% [markdown]
# El universal tiene artículos con cuerpo mucho más pequeños, podríamos decir que van al grano

# %%
# unimos los datasets
all_newspapers = pd.concat([clean_eluniversal, clean_elpais])

# Los agrupamos por su newspaper_uid
grouped = all_newspapers.groupby("newspaper_uid")

grouped.hist()
# Out:
# newspaper_uid
# elpais         [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %% [markdown]
# Aquí podemos observar que, mientras en el universal, la mayoría de palabras en el body se agrupan entre 10 y 20 palabras, en el país, lla mayoría se agrupan entre 600 y 700 palabras. Se hace el mismo análisis para el título

# %%
# agg --> generamos agregaciones
grouped["n_tokens_body"].agg(["min", "mean", "max"])
# Out:
#                min        mean   max
# newspaper_uid
# elpais         694  847.333333  1083
# eluniversal      0   16.925532    80

# %%
grouped.plot()
# Out:
# newspaper_uid
# elpais         AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
